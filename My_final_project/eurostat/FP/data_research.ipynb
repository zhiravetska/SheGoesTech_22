# %%
# 1. Source #1 EUROSTAT
# https://ec.europa.eu/eurostat/databrowser/view/nrg_bal_sd/default/table?lang=en
# Energy flow - Sankey diagram data (https://ec.europa.eu/eurostat/cache/metadata/en/nrg_bal_esms.htm)
import pandas as pd
df = pd.read_csv("nrg_bal_sd_linear.csv.gz")

# %%
df.head(2)
# Out:
#                 DATAFLOW        LAST UPDATE freq nrg_bal   siec  unit geo  \
# 0  ESTAT:NRG_BAL_SD(1.0)  03/01/22 23:00:00    A     AAS  C0121  KTOE  AL
# 1  ESTAT:NRG_BAL_SD(1.0)  03/01/22 23:00:00    A     AAS  C0121  KTOE  AL
#
#    TIME_PERIOD  OBS_VALUE  OBS_FLAG
# 0         1990       40.3       NaN
# 1         1991       39.0       NaN

# %%
df.describe(include='all')
# Out:
#                      DATAFLOW        LAST UPDATE    freq nrg_bal    siec  \
# count                  900539             900539  900539  900539  900539
# unique                      1                  1       1     113      36
# top     ESTAT:NRG_BAL_SD(1.0)  03/01/22 23:00:00       A     AAS   TOTAL
# freq                   900539             900539  900539   31507   99296
# mean                      NaN                NaN     NaN     NaN     NaN
# std                       NaN                NaN     NaN     NaN     NaN
# min                       NaN                NaN     NaN     NaN     NaN
# 25%                       NaN                NaN     NaN     NaN     NaN
# 50%                       NaN                NaN     NaN     NaN     NaN
# 75%                       NaN                NaN     NaN     NaN     NaN
# max                       NaN                NaN     NaN     NaN     NaN
#
#           unit        geo    TIME_PERIOD     OBS_VALUE  OBS_FLAG
# ...

# %%
#In Germany in 2020
# Final consumption [FC]
# Electricity [E7000]
# Unit of Measure - Thousand tonnes of oil equivalent [KTOE]
df[(df.nrg_bal=='FC')&(df.geo=='DE')&(df.TIME_PERIOD==2020)&(df.siec=='E7000')]
# Out:
#                     DATAFLOW        LAST UPDATE freq nrg_bal   siec  unit geo  \
# 87262  ESTAT:NRG_BAL_SD(1.0)  03/01/22 23:00:00    A      FC  E7000  KTOE  DE
#
#        TIME_PERIOD  OBS_VALUE  OBS_FLAG
# 87262         2020    41256.6       NaN

# %%
#I can't push
