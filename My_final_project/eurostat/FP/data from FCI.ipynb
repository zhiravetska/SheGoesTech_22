# %%
import pandas as pd

# %%
url = "https://www.fci.be/en/statistics/ByYear.aspx?year=2021"
url
# Out:
# 'https://www.fci.be/en/statistics/ByYear.aspx?year=2021'

# %%
dffcis = pd.read_html(url) 
type(dffcis)
# Out:
# list

# %%
len(dffcis)
# Out:
# 10

# %%
dffcis[7].head()
# Out:
#    0                                                  1   \
# 0 NaN  PUPPIES registered with the studbook and the a...
#
#                                                   2                    3   \
# 0  LITTERS registered with the studbook and the a...  CAC ALL-BREED SHOWS
#
#                       4                                     5   \
# 0  CACIB ALL-BREED SHOWS  FCI (breed, group, all-breed) JUDGES
#
#                             6   \
# 0  INDIVIDUAL MEMBERS (people)
#
#                                                7   \
# 0  member (breed, regional, sporting, etc.) CLUBS
#
#                                             8   \
# 0  PURE-BRED DOGS REGISTERED WITH THE STUDBOOK
#
#                                                   9   \
# 0  TOTAL number of PURE-BRED DOGS REGISTERED WITH...
#
#                                                   10  \
# 0  Approximate TOTAL number of DOGS (PURE-BRED OR...
#
#                                                   11
# ...

# %%
# Statistics of the FCI members & partners: 2021
dffcis[8].head()
# Out:
#           0        1        2      3    4       5        6       7        8   \
# 0    ALBANIA      NaN      NaN    NaN  NaN     NaN      NaN     NaN      NaN
# 1    ALGERIA      NaN      NaN    NaN  NaN     NaN      NaN     NaN      NaN
# 2  ARGENTINA  56414.0  12028.0  229.0  3.0   169.0      0.0    63.0  56741.0
# 3    ARMENIA      NaN      NaN    NaN  NaN     NaN      NaN     NaN      NaN
# 4  AUSTRALIA  78197.0  15281.0  716.0  1.0  1838.0  30272.0  1069.0  78580.0
#
#           9   10        11
# 0        NaN NaN       NaN
# 1        NaN NaN       NaN
# 2  1709069.0 NaN  215454.0
# 3        NaN NaN       NaN
# 4        NaN NaN   64405.0

# %%
df_dffcis = pd.concat([dffcis[7], dffcis[8]])
df_dffcis
# Out:
#                                     0   \
# 0                                  NaN
# 0                              ALBANIA
# 1                              ALGERIA
# 2                            ARGENTINA
# 3                              ARMENIA
# ..                                 ...
# 95                UNITED ARAB EMIRATES
# 96                             URUGUAY
# 97                          UZBEKISTAN
# 98  VENEZUELA (BOLIVARIAN REPUBLIC OF)
# 99                             VIETNAM
#
#                                                    1   \
# 0   PUPPIES registered with the studbook and the a...
# 0                                                 NaN
# 1                                                 NaN
# 2                                             56414.0
# 3                                                 NaN
# ..                                                ...
# 95                                                NaN
# ...
