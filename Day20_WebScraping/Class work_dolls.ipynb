# %%
import requests
import time 
import pandas as pd
 
from bs4 import BeautifulSoup

# %%
url = "https://www.ss.com/en/for-children/toys/dolls/"
url
# Out:
# 'https://www.ss.com/en/for-children/toys/dolls/'

# %%
req = requests.get(url) 
req.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(req.text, 'lxml') 

soup.title
# Out:
# <title>SS.COM Toys, swings - Dolls, Prices - Advertisements</title>

# %%
def getColList(soup):
    column_list = ["description","url"] 
    headline = soup.find("tr", {"id":"head_line"})
    headtds = headline.find_all("td")
    headcolumns = [el.text for el in headtds[1:]] 
    column_list += headcolumns
    return column_list

# %%
column_names = getColList(soup)
column_names
# Out:
# ['description', 'url', 'Name', 'Cond.', 'Price']

# %%
def getRowList(soup):
    trows = soup.find_all('tr')
    aprows = [row for row in trows if row.get('id',"").startswith("tr_") and not row.get('id',"").startswith("tr_bnr") ]
    return aprows

# %%
def getRow(row, colist=column_names):
    row_tds = row.find_all('td')
    rowDict = {}
    if len(row_tds) < 3: # a little sanity check
        print("Hmm bad row")
        return rowDict
    
    rowDict[colist[0]] = row_tds[2].text # so the big assumption is that we always get description in 3rd column
    rowDict[colist[1]] = "https://ss.com" + row_tds[1].find('a').get('href')
    for td,key in zip(row_tds[3:],colist[2:]): 
        rowDict[key] = td.text
    return rowDict

# %%
def getRows(rowlist,colist=column_names):
    return [getRow(row, colist=colist) for row in rowlist]

# %%
def getDFfromURL(url):
    
    req = requests.get(url)
    if req.status_code != 200:
        print("Request Fail with", req.status_code)
        return None 
    soup = BeautifulSoup(req.text, 'lxml')
    column_names = getColList(soup)
    rowlist = getRowList(soup)
    rows = getRows(rowlist,colist=column_names)
    return pd.DataFrame(rows, columns=column_names)

# %%
dolls = "https://www.ss.com/en/for-children/toys/dolls/"
idf = getDFfromURL(dolls)
idf.head(15)
# Out:
#                                           description  \
# 0   Disneja princese Frozen 2 komplekts Annas Box ...
# 1   Продаем куклу beby born в коробке горшочек в п...
# 2   Reborn lelle. \r\n50cm, 2kg. \r\n\r\nManeklīti...
# 3   Продаю комплект кукол, б/у.Riga district, Baldone
# 4   Pārdodu Barbi lelli. Kājas lokas, somiņa un ci...
# 5   Комплект кукол, б/у, + новый пазл.Riga distric...
# 6   Продаю комплект кукол в хорошем состоянии, б/у...
# 7   Продаю Машеньку с коляской и бутылочкой в идеа...
# 8   Крупные персонажи, полные озорства, с дружелюб...
# 9   Советская кукла Красная шапочка высота 45см. В...
# 10  Новая куколка в коробке. \r\n Ever After High ...
# 11  Lelle Mimi 42 cm (raud, runā, ar mānekli, mīks...
# 12  Lelle Mimi 42 cm (raud, runā, ar mānekli, mīks...
# 13  Lelle zīdainis Nica meitene ar sedziņu un māne...
# 14  Lelle zīdainis Bimba meitene ar spilvenu un mā...
#
#                                                   url  \
# 0   https://ss.com/msg/en/for-children/toys/dolls/...
# 1   https://ss.com/msg/en/for-children/toys/dolls/...
# 2   https://ss.com/msg/en/for-children/toys/dolls/...
# 25  Кукла Роберта 33 см, плачет, говорит, с соской...
# 26  Пупс 35 см + набор для кормления (4 элемента) ...
# 27   Pārdodu lol ar aksesuāriem 22€Riga, Vecmilgravis
# 28                  Pārdodu lol 20€Riga, Vecmilgravis
# 29  Продаём нашу личную коллекцию кукол монстр хай...
#
#                             Name Cond.     Price
# 0   Disneja princese Frozen 2 ko   new     10  €
# 1                      Baby born  used     25  €
# 2                         Reborn  used     70  €
# 3                         Lelles  used     10  €
# 4                          Barbi  used      5  €
# 5                         Lelles  used     12  €
# 6                     Simba toys  used     15  €
# 7                 Маша и медведь   new      7  €
# 8      Бренд: The Puppet Company   new     19  €
# 9                Красная шапочка  used     20  €
# 10               Ever after high   new     25  €
# 11        Lelle Mimi 42 cm (raud   new     64  €
# 12        Lelle Mimi 42 cm (raud   new     65  €
# 13      Lelle zīdainis Nica40 cm   new     62  €
# 14     Lelle zīdainis Bimbavinil   new     53  €
# 15      Кукла Анна 40 см (мягкое   new     60  €
# 16      Кукла Карла 40 см мягкая   new     52  €
# 17       Lelle Elena 35 cm Spāņu   new     59  €
# 18       Lelle Elena 35 cm spāņu   new     53  €
# 19               Baby Born 43 cm  used     25  €
# 20                       Unknown  used     10  €
# 21                        Barbie  used     10  €
# 22                        Līgava  used    100  €
# 23      Lelle Joelle 38 cm, raud   new     63  €
# 24     Lelle Roberta 33 cm, raud   new  44.68  €
# 25     Кукла Роберта 33 см, плач   new  48.40  €
# 26     Пупс 35 см + набор для ко   new  23.50  €
# 27                           Lol  used     20  €
# 28                           Lol  used     20  €
# 29                  Monster high  used     20  €

# %%
idf_pivoted = pd.pivot_table(data=idf, columns=["Cond."], values=["Price"])
idf_pivoted
# Out:
# C:\Users\zirav\AppData\Local\Temp\ipykernel_9272\3786467673.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   idf_pivoted = pd.pivot_table(data=idf, columns=["Cond."], values=["Price"])
# Empty DataFrame
# Columns: []
# Index: []

# %%
from matplotlib import ticker # ticker is a module that helps with formatting plots

# dataframe plot returns an axis object that we can use to customize the plot
ax = idf.plot(
    kind='bar', rot=0, xlabel='', ylabel='Price',
    figsize=(8, 1.5), title='New and used dolls prices'
)

# use month abbreviations for the ticks on the x-axis
ax.set_xticklabels(calendar.month_abbr[1:])

# show y-axis labels in millions instead of scientific notation
ax.yaxis.set_major_formatter(ticker.EngFormatter())

# customize the legend
ax.legend(title='', loc='center', bbox_to_anchor=(0.5, -0.3), ncol=3, frameon=False)

# change plot size in centimeters
ax.figure.set_size_inches(12, 2.5)

# %%
idf.to_excel("dolls.xlsx", encoding="UTF-8")
# Out:
# c:\Users\zirav\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)

# %%
dolls = pd.read_csv('C:\Users\zirav\Desktop\Accenture\Day20_WebScraping\dolls.xlsx', encoding="utf-8")
dolls
# Out:
#   Cell In [17], line 1
#     dolls = pd.read_csv('C:\Users\zirav\Desktop\Accenture\Day20_WebScraping\dolls.xlsx', encoding="utf-8")
#                                                                                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
